# %%
import numpy as np
import json

def get_captions():
    with open('./CS5785-final-data/captions.json') as data_train:
        return json.load(data_train)

# %%
captions = get_captions()
# Out:
# {u'3304712466.jpg': [u'Crowds cheer on cyclists as they complete a race to the finish .\n', u'Bicycle road racers passing a group of cheering spectators .\n', u'People on bicycles riding through a group of onlookers .\n', u'Bicycle racers being cheered on by some people .\n', u'Racers on bikes riding past a crowd .\n'], u'2596293451.jpg': [u'A man kneeling by a bright red kayak with several kayak and canoe business signs behind him .\n', u'A man dressed in red plaid shirt crouches next to a sign that reads " Crooked Run " .\n', u'A man in a red shirt posing next to a red canoe by a sign for Crooked Run Creek .\n', u'A man is squatting in front of a canoe and kayak rental display .\n', u'A man posed up at blackwater cypress swamp .\n'], u'16396183.jpg': [u'Two men are standing outdoors on a sunny day holding pieces of a new item , possibly a small grill , while one of the men studies the assembly instructions .\n', u'Two men , one in a gray shirt and one in a black shirt and orange sh
# ...
